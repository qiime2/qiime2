# %%
import os

from qiime2.sdk import usage
from qiime2.plugins import dummy_plugin

##################
print('case1')

action = dummy_plugin.actions.concatenate_ints
output_dir = '/home/matthew/Desktop/noice'

use = usage.NoOpUsage()
scope = usage.Scope()

with use.bind(scope):
    for example in action.examples:
        example(use)
        
for record in scope:
    path = os.path.join(output_dir, record.name)
    data = record.factory()
    if record.type == 'artifact':
        path += '.qza'
        data.save(path)
        hint = repr(data.type)
    elif record.type == 'metadata':
        path += '.tsv'
        data.save(path)
        hint = 'Metadata'
    elif record.type == 'file':
        util.duplicate(data, path)
        hint = 'file'
    else:
        raise NotImplementedError

    print(hint, path)
    
##################
print('case2')

class MyUsage(usage.Usage):
    def __init__(self):
        super().__init__()
        self.state = []

    def comment(self, comment):
        self.state.append('# %s' % comment)
    
    def action(self, action, inputs, outputs):
        self.state.append('qiime %s %s %s' % (action, inputs, outputs))
        
    def import_file(self, type, input_name, output_name=None, format=None):
        return None
    
    def export_file(self, input_name, output_name, format=None):
        return None


use = MyUsage()
scope = usage.Scope()

with use.bind(scope):
    for example in action.examples:
        example(use)
    
for transaction in use.state:
    print(transaction)

##################
print('case3')

use = usage.ExecutionUsage()

for example in action.examples:
    scope = usage.Scope()
    with use.bind(scope):
        example(use)
    print(example)
    for record in scope:
        print(record)
# Out:
# case1
# IntSequence1 /home/matthew/Desktop/noice/byod.qza
# IntSequence1 /home/matthew/Desktop/noice/ints2.qza
# IntSequence2 /home/matthew/Desktop/noice/this_one_is_important.qza
# case2
# # big data == concatenating ints
# qiime <method qiime2.plugins.dummy_plugin.methods.concatenate_ints> {'ints1': 'byod', 'ints2': 'ints2', 'ints3': 'this_one_is_important', 'int1': 4, 'int2': 2} {'concatenated_ints': 'youre_just_a_copy_of_an_imitation'}
# # as you can clearly see, p == np
# # big data == concatenating ints
# qiime <method qiime2.plugins.dummy_plugin.methods.concatenate_ints> {'ints1': 'byod', 'ints2': 'ints2', 'ints3': 'this_one_is_important', 'int1': 4, 'int2': 2} {'concatenated_ints': 'youre_just_a_copy_of_an_imitation'}
# # as you can clearly see, p == np
# qiime <method qiime2.plugins.dummy_plugin.methods.concatenate_ints> {'ints1': 'youre_just_a_copy_of_an_imitation', 'ints2': 'youre_just_a_copy_of_an_imitation', 'ints3': 'this_one_is_important', 'int1': 6, 'int2': 7} {'concatenated_ints': 'well_well_well_what_do_we_have_here'}
# # fin
# case3
# <function concatenate_ints_simple at 0x7fec178d7048>
# ScopeRecord(name='byod', type='artifact', factory=<function ints1_factory at 0x7fec178cfe18>)
# ScopeRecord(name='ints2', type='artifact', factory=<function ints2_factory at 0x7fec178cfea0>)
# ScopeRecord(name='this_one_is_important', type='artifact', factory=<function ints3_factory at 0x7fec178cff28>)
# ScopeRecord(name='youre_just_a_copy_of_an_imitation', type='artifact', factory=<function ExecutionUsage.action.<locals>.<lambda> at 0x7fec426c6ea0>)
# <function concatenate_ints_complex at 0x7fec178d70d0>
# ScopeRecord(name='byod', type='artifact', factory=<function ints1_factory at 0x7fec178cfe18>)
# ScopeRecord(name='ints2', type='artifact', factory=<function ints2_factory at 0x7fec178cfea0>)
# ScopeRecord(name='this_one_is_important', type='artifact', factory=<function ints3_factory at 0x7fec178cff28>)
# ScopeRecord(name='youre_just_a_copy_of_an_imitation', type='artifact', factory=<function ExecutionUsage.action.<locals>.<lambda> at 0x7fec41d04620>)
# ScopeRecord(name='well_well_well_what_do_we_have_here', type='artifact', factory=<function ExecutionUsage.action.<locals>.<lambda> at 0x7fec42712c80>)
